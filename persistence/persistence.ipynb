# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model = 'gemini-2.5-flash'
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza chef get a part-time job?\nBecause he kneaded the extra dough!',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef get a part-time job?\nBecause he kneaded the extra dough!', 'explanation': 'This joke is a pun, which relies on words that sound alike but have different meanings.\n\nHere\'s the breakdown:\n\n1.  **"Kneaded" vs. "Needed":**\n    *   **"Kneaded"** (pronounced "need-ed") is what a pizza chef does with actual pizza dough – they work it with their hands to prepare it.\n    *   **"Needed"** (pronounced "need-ed") means to require something, in this case, money.\n\n2.  **"Dough":**\n    *   **"Dough"** is the primary ingredient a pizza chef works with.\n    *   **"Dough"** is also a common slang term for **money**.\n\nSo, the joke works because:\n\n*   A chef *literally* **kneads dough** (pizza dough) as part of their job.\n*   Someone getting a part-time job *figuratively* **needed extra dough** (extra money).\n\nThe humor comes from the clever wordplay that connects the chef\'s profession (kneading dough) with a com
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef get a part-time job?\nBecause he kneaded the extra dough!', 'explanation': 'This joke is a pun, which relies on words that sound alike but have different meanings.\n\nHere\'s the breakdown:\n\n1.  **"Kneaded" vs. "Needed":**\n    *   **"Kneaded"** (pronounced "need-ed") is what a pizza chef does with actual pizza dough – they work it with their hands to prepare it.\n    *   **"Needed"** (pronounced "need-ed") means to require something, in this case, money.\n\n2.  **"Dough":**\n    *   **"Dough"** is the primary ingredient a pizza chef works with.\n    *   **"Dough"** is also a common slang term for **money**.\n\nSo, the joke works because:\n\n*   A chef *literally* **kneads dough** (pizza dough) as part of their job.\n*   Someone getting a part-time job *figuratively* **needed extra dough** (extra money).\n\nThe humor comes from the clever wordplay that connects the chef\'s profession (kneading dough) with a co
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'What do you call fake pasta?\nAn **impasta!**',
#  'explanation': 'This is a classic pun that plays on the similar sounds of two words with very different meanings:\n\n1.  **"Pasta"**: This is the food item itself, mentioned in the question.\n2.  **"Impostor"**: An impostor is a person who pretends to be someone else in order to deceive others.\n\nThe joke works by taking the word "**impostor**" (meaning a fake or deceiver) and changing the ending to "**pasta**" to create "impasta."\n\nSo, you\'re calling fake pasta an "impostor" (a fake) by cleverly changing the end of the word to "pasta" to fit the food theme. The humor comes from the unexpected but phonetically similar wordplay.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef get a part-time job?\nBecause he kneaded the extra dough!', 'explanation': 'This joke is a pun, which relies on words that sound alike but have different meanings.\n\nHere\'s the breakdown:\n\n1.  **"Kneaded" vs. "Needed":**\n    *   **"Kneaded"** (pronounced "need-ed") is what a pizza chef does with actual pizza dough – they work it with their hands to prepare it.\n    *   **"Needed"** (pronounced "need-ed") means to require something, in this case, money.\n\n2.  **"Dough":**\n    *   **"Dough"** is the primary ingredient a pizza chef works with.\n    *   **"Dough"** is also a common slang term for **money**.\n\nSo, the joke works because:\n\n*   A chef *literally* **kneads dough** (pizza dough) as part of their job.\n*   Someone getting a part-time job *figuratively* **needed extra dough** (extra money).\n\nThe humor comes from the clever wordplay that connects the chef\'s profession (kneading dough) with a com
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef get a part-time job?\nBecause he kneaded the extra dough!', 'explanation': 'This joke is a pun, which relies on words that sound alike but have different meanings.\n\nHere\'s the breakdown:\n\n1.  **"Kneaded" vs. "Needed":**\n    *   **"Kneaded"** (pronounced "need-ed") is what a pizza chef does with actual pizza dough – they work it with their hands to prepare it.\n    *   **"Needed"** (pronounced "need-ed") means to require something, in this case, money.\n\n2.  **"Dough":**\n    *   **"Dough"** is the primary ingredient a pizza chef works with.\n    *   **"Dough"** is also a common slang term for **money**.\n\nSo, the joke works because:\n\n*   A chef *literally* **kneads dough** (pizza dough) as part of their job.\n*   Someone getting a part-time job *figuratively* **needed extra dough** (extra money).\n\nThe humor comes from the clever wordplay that connects the chef\'s profession (kneading dough) with a co
# ...

# %% [markdown]
# ## Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f1239fa-2ab2-6186-8000-0c4b60ba5e1a"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f1239fa-2ab2-6186-8000-0c4b60ba5e1a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-03-19T14:26:36.109234+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1239fa-2aae-6ed8-bfff-0d60f76d0081'}}, tasks=(PregelTask(id='5b7254a9-8631-9941-7cee-903200d1aea7', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza chef get a part-time job?\nBecause he kneaded the extra dough!'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f1239fa-2ab2-6186-8000-0c4b60ba5e1a"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza get a bad review?\n\nBecause it was too **cheesy**!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a bad review?\n\nBecause it was too **cheesy**!', 'explanation': 'This joke plays on the **double meaning of the word "cheesy."**\n\nHere\'s the breakdown:\n\n1.  **Literal Meaning (Pizza Context):** When you think of a pizza being "cheesy," you usually think of it having **a lot of cheese**. For most pizza lovers, this is a *good* thing! It\'s desirable. So, if a pizza was "too cheesy" in this sense, it\'s unlikely to get a *bad* review.\n\n2.  **Figurative/Slang Meaning (Joke Context):** "Cheesy" also has a common colloquial meaning, referring to something that is **tacky, corny, unoriginal, overly sentimental, or trying too hard to be impressive but failing.** Think of a "cheesy pickup line" or a "cheesy pop song."\n\n**The Joke\'s Punchline:**\n\nThe humor comes from the **unexpected switch** between these two meanings.\n*   The setup ("Why did the pizza get a bad review?") leads you to expect a culinary reas
# ...

# %% [markdown]
# ## Updating state

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f1239fa-2ab2-6186-8000-0c4b60ba5e1a", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f123a24-d7ce-69af-8001-305e1b159785'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f123a24-d7ce-69af-8001-305e1b159785'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-03-19T14:45:41.690185+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1239fa-2ab2-6186-8000-0c4b60ba5e1a'}}, tasks=(PregelTask(id='455a7547-c514-97f2-b3c3-76f36402f7f5', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f1239fa-2ab2-6186-8000-0c4b60ba5e1a"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza get a bad review?\n\nBecause it was too **crusty**!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the bank?\n\nTo get more dough!', 'explanation': 'This is a classic pun! The humor comes from the **double meaning of the word "dough."**\n\nHere\'s the breakdown:\n\n1.  **Dough (as in pizza):** This is the literal, uncooked mixture of flour, water, and yeast that forms the base of a pizza. A pizza is made *from* dough.\n2.  **Dough (as in money):** This is a common, informal slang term for money. People go to a bank to get money.\n\nThe joke works because:\n\n*   The setup ("Why did the pizza go to the bank?") makes you think of what people usually do at banks – get money.\n*   The punchline ("To get more dough!") cleverly plays on this. You initially think of **money** (which you get at a bank), but then you realize it also refers to the **pizza dough** (the literal ingredient a pizza is made of).\n\nThe unexpected twist of connecting the pizza\'s literal \'dough\' to the slang term for money is what makes i
# ...
